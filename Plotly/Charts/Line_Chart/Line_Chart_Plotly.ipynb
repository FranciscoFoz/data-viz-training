# %% [markdown]
# # Line Chart Plotly

# %% [markdown]
# Requirements:
#
# pandas==1.4.2

# %%
import pandas as pd

# %% [markdown]
# ### Importando dados

# %%
visitas_museu = pd.read_csv(r"C:\Users\franc\Documents\GitHub_VsCode\Plotly_estudos\Datasets\Museum Los Angeles\museum-visitors.csv")
visitas_museu
# Out:
#                       Month  America Tropical Interpretive Center  \
# 0   2014-01-01T00:00:00.000                                  6602
# 1   2014-02-01T00:00:00.000                                  5029
# 2   2014-03-01T00:00:00.000                                  8129
# 3   2014-04-01T00:00:00.000                                  2824
# 4   2014-05-01T00:00:00.000                                 10694
# ..                      ...                                   ...
# 85  2021-02-01T00:00:00.000                                     0
# 86  2021-03-01T00:00:00.000                                     0
# 87  2021-04-01T00:00:00.000                                     0
# 88  2021-05-01T00:00:00.000                                     0
# 89  2021-06-01T00:00:00.000                                  1047
#
#     Avila Adobe  Chinese American Museum  Gateway to Nature Center  \
# 0         24778                     1581                       NaN
# ...

# %% [markdown]
# ### Manipulando dados

# %%
chinese_american_museu = visitas_museu.iloc[:,[0,3]]
chinese_american_museu
# Out:
#                       Month  Chinese American Museum
# 0   2014-01-01T00:00:00.000                     1581
# 1   2014-02-01T00:00:00.000                     1785
# 2   2014-03-01T00:00:00.000                     3229
# 3   2014-04-01T00:00:00.000                     2129
# 4   2014-05-01T00:00:00.000                     3676
# ..                      ...                      ...
# 85  2021-02-01T00:00:00.000                        0
# 86  2021-03-01T00:00:00.000                        0
# 87  2021-04-01T00:00:00.000                        0
# 88  2021-05-01T00:00:00.000                        0
# 89  2021-06-01T00:00:00.000                        0
#
# [90 rows x 2 columns]

# %% [markdown]
# ## Visualizando com o pandas

# %%
chinese_american_museu.head(50)
# Out:
#                       Month  Chinese American Museum
# 0   2014-01-01T00:00:00.000                     1581
# 1   2014-02-01T00:00:00.000                     1785
# 2   2014-03-01T00:00:00.000                     3229
# 3   2014-04-01T00:00:00.000                     2129
# 4   2014-05-01T00:00:00.000                     3676
# 5   2014-06-01T00:00:00.000                     2121
# 6   2014-07-01T00:00:00.000                     2239
# 7   2014-08-01T00:00:00.000                     1769
# 8   2014-09-01T00:00:00.000                     1073
# 9   2014-10-01T00:00:00.000                     1979
# 10  2014-11-01T00:00:00.000                     2404
# 11  2014-12-01T00:00:00.000                     1319
# 12  2015-01-01T00:00:00.000                     1823
# 13  2015-02-01T00:00:00.000                     1558
# 14  2015-03-01T00:00:00.000                     2336
# 15  2015-04-01T00:00:00.000                     3057
# 16  2015-05-01T00:00:00.000                     4009
# ...

# %%
pd.options.plotting.backend = 'plotly'
chinese_american_museu.plot(x='Month',y='Chinese American Museum',
                         title='Quantidade de visitas ao Chinese American Museum')

# %%
chinese_american_museu = chinese_american_museu.sort_values(by='Month')

# %%
pd.options.plotting.backend = 'plotly'
chinese_american_museu.plot(x='Month',y='Chinese American Museum',
                         title='Quantidade de visitas ao Chinese American Museum')

# %% [markdown]
# ## *"Gráficos de dispersão conectados"*

# %% [markdown]
# # Visualizando com o Plotly express

# %%
import plotly.express as px

# %%
px.line(chinese_american_museu, x='Month', y='Chinese American Museum', 
        title='Quantidade de visitas ao Chinese American Museum')

# %% [markdown]
# # Line Plot with go.Scatter

# %%
import plotly.graph_objects as go

# %%
chinese_american_museu
# Out:
#                       Month  Chinese American Museum
# 0   2014-01-01T00:00:00.000                     1581
# 1   2014-02-01T00:00:00.000                     1785
# 2   2014-03-01T00:00:00.000                     3229
# 3   2014-04-01T00:00:00.000                     2129
# 4   2014-05-01T00:00:00.000                     3676
# ..                      ...                      ...
# 85  2021-02-01T00:00:00.000                        0
# 86  2021-03-01T00:00:00.000                        0
# 87  2021-04-01T00:00:00.000                        0
# 88  2021-05-01T00:00:00.000                        0
# 89  2021-06-01T00:00:00.000                        0
#
# [90 rows x 2 columns]

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=chinese_american_museu['Month'], y=chinese_american_museu['Chinese American Museum']))

annotations = []

annotations.append(dict(xref='paper', yref='paper', x=0.0, y=1.15,
                              xanchor='left', yanchor='bottom',
                              text='Quantidade de visitas ao Chinese American Museum',
                              font=dict(family='Arial',
                                        size=25,
                                        color='black'),
                              showarrow=False))

fig.update_layout(annotations=annotations)

fig.show()
